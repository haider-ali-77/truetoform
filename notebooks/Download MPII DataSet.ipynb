# %%
cd ~/datasets/mpii
# Out:
# /home/usman/datasets/mpii

# %%
mkdir data

# %%
# !wget https://datasets.d2.mpi-inf.mpg.de/andriluka14cvpr/mpii_human_pose_v1.tar.gz
# Out:
# --2022-01-04 13:19:04--  https://datasets.d2.mpi-inf.mpg.de/andriluka14cvpr/mpii_human_pose_v1.tar.gz
# Resolving datasets.d2.mpi-inf.mpg.de (datasets.d2.mpi-inf.mpg.de)... 139.19.206.177
# Connecting to datasets.d2.mpi-inf.mpg.de (datasets.d2.mpi-inf.mpg.de)|139.19.206.177|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12088943206 (11G) [application/x-gzip]
# Saving to: ‘mpii_human_pose_v1.tar.gz’
#
# mpii_human_pose_v1. 100%[===================>]  11.26G  5.81MB/s    in 14m 29s
#
# 2022-01-04 13:33:34 (13.3 MB/s) - ‘mpii_human_pose_v1.tar.gz’ saved [12088943206/12088943206]

# %%
ls
# Out:
# data/  mpii_human_pose_v1.tar.gz

# %%
import tarfile
fname = 'mpii_human_pose_v1.tar.gz'

# %%
tar = tarfile.open(fname, "r:gz")

# %%
tar.extractall('data')

# %%
tar.close()

# %%
# !wget https://datasets.d2.mpi-inf.mpg.de/andriluka14cvpr/mpii_human_pose_v1_u12_2.zip
# Out:
# --2022-01-04 14:17:09--  https://datasets.d2.mpi-inf.mpg.de/andriluka14cvpr/mpii_human_pose_v1_u12_2.zip
# Resolving datasets.d2.mpi-inf.mpg.de (datasets.d2.mpi-inf.mpg.de)... 139.19.206.177
# Connecting to datasets.d2.mpi-inf.mpg.de (datasets.d2.mpi-inf.mpg.de)|139.19.206.177|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12340483 (12M) [application/zip]
# Saving to: ‘mpii_human_pose_v1_u12_2.zip’
#
# mpii_human_pose_v1_ 100%[===================>]  11.77M  9.98MB/s    in 1.2s
#
# 2022-01-04 14:17:11 (9.98 MB/s) - ‘mpii_human_pose_v1_u12_2.zip’ saved [12340483/12340483]

# %%
mkdir keypoints

# %%
import zipfile
with zipfile.ZipFile('mpii_human_pose_v1_u12_2.zip', 'r') as zip_ref:
    zip_ref.extractall('keypoints')
